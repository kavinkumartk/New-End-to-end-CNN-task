# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping
import matplotlib.pyplot as plt


data_dir = "flowers"

img_height, img_width = 150, 150
batch_size = 32

train_datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2,  
)

train_generator = train_datagen.flow_from_directory(
    data_dir,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode="categorical",
    subset="training"
)

val_generator = train_datagen.flow_from_directory(
    data_dir,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode="categorical",
    subset="validation"
)

model = Sequential([
    Conv2D(32, (3,3), activation='relu', input_shape=(img_height, img_width, 3)),
    MaxPooling2D(pool_size=(2,2)),

    Conv2D(64, (3,3), activation='relu'),
    MaxPooling2D(pool_size=(2,2)),

    Conv2D(128, (3,3), activation='relu'),
    MaxPooling2D(pool_size=(2,2)),

    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(train_generator.num_classes, activation='softmax')
])

model.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"])

early_stop = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

history = model.fit(
    train_generator,
    epochs=50,
    validation_data=val_generator,
    callbacks=[early_stop]
)

plt.plot(history.history['accuracy'], label="Train Acc")
plt.plot(history.history['val_accuracy'], label="Val Acc")
plt.legend()
plt.show()


model.save("flower_cnn.h5")
# Out:
# Found 3457 images belonging to 5 classes.
# Found 860 images belonging to 5 classes.
# c:\Users\kavin\anaconda4\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\kavin\anaconda4\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 85s 736ms/step - accuracy: 0.4018 - loss: 1.3674 - val_accuracy: 0.5000 - val_loss: 1.1583 - learning_rate: 0.0010
# Epoch 2/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 58s 528ms/step - accuracy: 0.5123 - loss: 1.1783 - val_accuracy: 0.5802 - val_loss: 1.0954 - learning_rate: 0.0010
# Epoch 3/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 59s 540ms/step - accuracy: 0.5829 - loss: 1.0768 - val_accuracy: 0.6198 - val_loss: 1.0222 - learning_rate: 0.0010
# Epoch 4/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 55s 504ms/step - accuracy: 0.6098 - loss: 0.9997 - val_accuracy: 0.6360 - val_loss: 0.9200 - learning_rate: 0.0010
# Epoch 5/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 53s 490ms/step - accuracy: 0.6309 - loss: 0.9472 - val_accuracy: 0.6686 - val_loss: 0.9001 - learning_rate: 0.0010
# Epoch 6/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 53s 482ms/step - accuracy: 0.6419 - loss: 0.9311 - val_accuracy: 0.6605 - val_loss: 0.8648 - learning_rate: 0.0010
# Epoch 7/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 53s 484ms/step - accuracy: 0.6662 - loss: 0.8706 - val_accuracy: 0.6465 - val_loss: 0.9073 - learning_rate: 0.0010
# Epoch 8/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 60s 551ms/step - accuracy: 0.6798 - loss: 0.8575 - val_accuracy: 0.6977 - val_loss: 0.8070 - learning_rate: 0.0010
# Epoch 9/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 62s 566ms/step - accuracy: 0.6980 - loss: 0.7921 - val_accuracy: 0.6465 - val_loss: 0.9378 - learning_rate: 0.0010
# Epoch 10/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 60s 547ms/step - accuracy: 0.6980 - loss: 0.8066 - val_accuracy: 0.6895 - val_loss: 0.7978 - learning_rate: 0.0010
# Epoch 11/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 60s 546ms/step - accuracy: 0.7026 - loss: 0.7724 - val_accuracy: 0.6919 - val_loss: 0.8114 - learning_rate: 0.0010
# Epoch 12/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 57s 525ms/step - accuracy: 0.7104 - loss: 0.7555 - val_accuracy: 0.6407 - val_loss: 0.9572 - learning_rate: 0.0010
# Epoch 13/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 72s 663ms/step - accuracy: 0.7032 - loss: 0.8098 - val_accuracy: 0.6581 - val_loss: 0.9286 - learning_rate: 0.0010
# Epoch 14/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 85s 783ms/step - accuracy: 0.7015 - loss: 0.7723 - val_accuracy: 0.7000 - val_loss: 0.7769 - learning_rate: 5.0000e-04
# Epoch 15/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 83s 762ms/step - accuracy: 0.7382 - loss: 0.6932 - val_accuracy: 0.7023 - val_loss: 0.7783 - learning_rate: 5.0000e-04
# Epoch 16/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 84s 773ms/step - accuracy: 0.7559 - loss: 0.6631 - val_accuracy: 0.7174 - val_loss: 0.7402 - learning_rate: 5.0000e-04
# Epoch 17/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 97s 891ms/step - accuracy: 0.7561 - loss: 0.6487 - val_accuracy: 0.7128 - val_loss: 0.7703 - learning_rate: 5.0000e-04
# Epoch 18/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 96s 879ms/step - accuracy: 0.7642 - loss: 0.6275 - val_accuracy: 0.7256 - val_loss: 0.7874 - learning_rate: 5.0000e-04
# Epoch 19/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 86s 785ms/step - accuracy: 0.7654 - loss: 0.6024 - val_accuracy: 0.7256 - val_loss: 0.7822 - learning_rate: 5.0000e-04
# Epoch 20/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 219s 2s/step - accuracy: 0.7744 - loss: 0.5755 - val_accuracy: 0.7244 - val_loss: 0.7539 - learning_rate: 2.5000e-04
# Epoch 21/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 97s 885ms/step - accuracy: 0.7796 - loss: 0.5750 - val_accuracy: 0.7326 - val_loss: 0.7314 - learning_rate: 2.5000e-04
# Epoch 22/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 96s 876ms/step - accuracy: 0.7822 - loss: 0.5670 - val_accuracy: 0.7174 - val_loss: 0.7376 - learning_rate: 2.5000e-04
# Epoch 23/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 94s 862ms/step - accuracy: 0.7935 - loss: 0.5424 - val_accuracy: 0.7384 - val_loss: 0.7569 - learning_rate: 2.5000e-04
# Epoch 24/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 95s 870ms/step - accuracy: 0.7923 - loss: 0.5471 - val_accuracy: 0.7477 - val_loss: 0.7421 - learning_rate: 2.5000e-04
# Epoch 25/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 96s 882ms/step - accuracy: 0.7946 - loss: 0.5272 - val_accuracy: 0.7326 - val_loss: 0.7540 - learning_rate: 1.2500e-04
# Epoch 26/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 95s 873ms/step - accuracy: 0.8050 - loss: 0.5209 - val_accuracy: 0.7372 - val_loss: 0.7453 - learning_rate: 1.2500e-04
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
